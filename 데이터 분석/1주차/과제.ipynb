# %%
import pandas as pd

# %% [markdown]
# # 과제
# - 통합 연비가 가장 좋은 차는 무엇일까?
# - 통합 연비가 가장 안 좋은 차는 무엇일까?

# %% [markdown]
# # 과제
# - 중첩 조건문을 이용해서 다양한 파생변수를 만들기
# - ex) 연비 또는 새로운 파생변수의 값에 따라 등급을 더 다양하게 나누기. 10이하 C, 10~15 B, 등

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  통합 연비
# 0    compact   23.5
# 1    compact   25.0
# 2    compact   25.5
# 3    compact   25.5
# 4    compact   21.0
# ..       ...    ...
# 229  midsize   23.5
# 230  midsize   25.0
# 231  midsize   21.0
# 232  midsize   22.0
# 233  midsize   21.5
#
# [234 rows x 12 columns]

# %%
mpg['통합 연비'] = (mpg['cty']+mpg['hwy'])/2

# %%
mpg['통합 연비'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: 통합 연비, dtype: float64

# %%
import numpy as np

# %%
mpg['g/b'] = np.where(mpg['통합 연비']>=23.5, 'A', 'B')
mpg['g/b'] = np.where(mpg['통합 연비']>=20.5 & mpg['통합 연비']<23.5, 'B')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_25160\1646515379.py in <module>
# ----> 1 mpg['g/b'] = np.where(mpg['통합 연비']>=23.5, 'A')
#       2 mpg['g/b'] = np.where(mpg['통합 연비']>=20.5 & mpg['통합 연비']<23.5, 'B')
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given
